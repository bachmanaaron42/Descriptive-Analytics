# %% [markdown]
# # Recent College Graduates Analysis
#
# This analysis will look at data regarding recent college graduates such as major, median salary, number of men, number of women, full and part time employment, and more.

# %%
import pandas as pd
import matplotlib as plt

# displays plots in line
# %matplotlib inline

# read the csv file into a pandas dataframe
recent_grads = pd.read_csv('recent-grads.csv')

# %%
# explore the first and last few rows using df.head() and df.tail()
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
# create quick summary statistics for the data
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
# return the number of rows in the data set
raw_count = len(recent_grads)
print(raw_count)
# Out:
# 173

# %%
# drop rows with NULL values
recent_grads = recent_grads.dropna()
cleaned_data_count = len(recent_grads)
print(cleaned_data_count)
# Out:
# 172

# %%
# create 6 scatter plots exploring the relationship between various columns
ax1 = recent_grads.plot(x='Sample_size', y='Median', kind='scatter')
ax1.set_title('Sample Size and Median')

ax2 = recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')
ax2.set_title('Sample Size and Unemployment Rate')

ax3 = recent_grads.plot(x='Full_time', y='Median', kind='scatter')
ax3.set_title('Full Time and Median')

ax4 = recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter')
ax4.set_title('Share Women and Unemployment Rate')

ax5 = recent_grads.plot(x='Men', y='Median', kind='scatter')
ax5.set_title('Men and Median')

ax6 = recent_grads.plot(x='Women', y='Median', kind='scatter')
ax6.set_title('Women and Median')

# %% [markdown]
# # Scatterplot analysis
#
# The following points can be noted after analysis from the scatter plot data:
#  - There is no relationship between major popularity and median salary
#  - There is no relationship between majors that were majority female and median salary
#  - There is no relationship between the number of full time employees and median salary

# %%
# create a histogram for various columns to see distribution of values
recent_grads['Sample_size'].hist(bins=20, range=(0, 4500))

# %%
# create a histogram for various columns to see distribution of values
recent_grads['Median'].hist(bins=11, range=(0, 110000))

# %%
# create a histogram for various columns to see distribution of values
recent_grads['Employed'].hist(bins=15, range=(0, 70000))

# %%
# create a histogram for various columns to see distribution of values
recent_grads['Full_time'].hist(bins=20, range=(0, 75000))

# %%
# create a histogram for various columns to see distribution of values
recent_grads['ShareWomen'].hist(bins=10, range=(0, 1))

# %%
# create a histogram for various columns to see distribution of values
recent_grads['Unemployment_rate'].hist(bins=20, range=(0, .2))

# %%
# create a histogram for various columns to see distribution of values
recent_grads['Men'].hist(bins=10, range=(0, 100000))

# %%
# create a histogram for various columns to see distribution of values
recent_grads['Women'].hist(bins=10, range=(0, 100000))

# %% [markdown]
# # Histogram analysis
#
# Base on the histograms above, there are 2 important points:
#
#  - Approximately 55% of majors are predominantly female, and approximately 45% predominantly male. There are 3 majors that are only male and 8 majors that are only female.
#  - The most common median salary is between 30,000 USD and 50,000 USD

# %%
import pandas.plotting as pltng

# create a scatter matrix (both a histogram and scatter plot)
pltng.scatter_matrix(recent_grads[['Sample_size', 'Median']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fca92513898>,
# ...
#       dtype=object)

# %% [markdown]
# # Scatter Matrix Analysis
#
# There appears to be no relationship between the popularity of a major and the median salary after graduation.

# %%
# insert a bar plot to see the ShareWomen data for the first 10 and last 10 rows
recent_grads[:9].plot.bar(x='Major', y='ShareWomen')
recent_grads[161:171].plot.bar(x='Major', y='ShareWomen')

# %%
# insert a bar plot to see the unemployment data for the first 10 and last 10 rows
recent_grads[:9].plot.bar(x='Major', y='Unemployment_rate')
recent_grads[161:171].plot.bar(x='Major', y='Unemployment_rate')

# %% [markdown]
# # Bar chart analysis
#
# As you can see from the bar charts pictured above, all of the last 10 majors (in terms of median salary) were predominantly women in the major, whereas only 1 of the top 10 majors was predominantly women in the major.
#
# Also, there isn't a significant (in terms of unemployment rate) between the top 10 and bottom 10 majors.
